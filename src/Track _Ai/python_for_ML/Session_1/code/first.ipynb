# %%
print('hello world')
# Out:
# hello world

# %%
x=5
type(x)
# Out:
# int

# %%
name="Ereny"
my_age=20
my_course="Machine learning"
print(f'my name is {name} and my age is {my_age} and my course is {my_course}')
# Out:
# my name is Ereny and my age is 20 and my course is Machine learning

# %%
name="Amit learning"
print(name[0:4])
print(name[-1])
# Out:
# Amit
# g
