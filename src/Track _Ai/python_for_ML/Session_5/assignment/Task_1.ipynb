# %%
class MultiplicationTable:
    """
    Handles the multiplication table of a number.
    """

    def __init__(self, number):
        self.number = number

    def multiplication_table(self):
        """
        Prints the multiplication table of the number.
        """

        for i in range(1, 11):
            print(f"{self.number} x {i} = {self.number * i}")

# %%
number = int(input("Enter a number: "))
task1 = MultiplicationTable(number)
task1.multiplication_table()
# Out:
# 4 x 1 = 4
# 4 x 2 = 8
# 4 x 3 = 12
# 4 x 4 = 16
# 4 x 5 = 20
# 4 x 6 = 24
# 4 x 7 = 28
# 4 x 8 = 32
# 4 x 9 = 36
# 4 x 10 = 40
