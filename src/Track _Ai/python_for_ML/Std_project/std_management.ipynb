# %%
class Student:
    _id_counter =1
    def __init__(self,name):
        self.student_id=Student._id_counter
        Student._id_counter +=1
        self.name=name
        self.grades={}
        self.enrolled_course=[]
    def __str__(self):
        return f"Student_id {self.student_id} name : {self.name} , Grades : {self.grades}, enroll_course: {self.enrolled_course}"
    def __repr__(self) ->str:
        return f"Student_id {self.student_id} name : {self.name} , Grades : {self.grades}, enroll_course: {self.enrolled_course}"
    
    
    def add_grade(self,course_id,grade):
        if not       0 <= grade<=100:
            raise ValueError("grade must between 0,100")
        self.grades[course_id]=grade
        
    def enroll_in_course(selfe,course):
        if course in selfe.enrolled_course:
            raise ValueError("Student already in this course")
        else:
            selfe.enrolled_course.append(course)

# %%
s1=Student("ereny")
#str(s1)
repr(s1)
s1.add_grade(1,90)
str(s1)
s1.enroll_in_course("ML")
str(s1)
# Out:
# "Student_id 4 name : ereny , Grades : {1: 90}, enroll_course: ['ML']"

# %%
class Course:
    _id_counter =1
    def __init__(self,name):
        self.course_id=Course._id_counter
        Course._id_counter +=1
        self.name=name
        self.enrolled_student =[]

# %%
import unittest
class Student:
    _id_counter =1
    def __init__(self,name):
        self.student_id=Student._id_counter
        Student._id_counter +=1
        self.name=name
        self.grades={}
        self.enrolled_course=[]
    def __str__(self):
        return f"Student_id {self.student_id} name : {self.name} , Grades : {self.grades}, enroll_course: {self.enrolled_course}"
    def __repr__(self) ->str:
        return f"Student_id {self.student_id} name : {self.name} , Grades : {self.grades}, enroll_course: {self.enrolled_course}"
    
    
    def add_grade(self,course_id,grade):
        if not       0 <= grade<=100:
            raise ValueError("grade must between 0,100")
        self.grades[course_id]=grade
        
    def enroll_in_course(selfe,course):
        if course in selfe.enrolled_course:
            raise ValueError("Student already in this course")
        else:
            selfe.enrolled_course.append(course)



import unittest
 
class TestStudent(unittest.TestCase):
   
   
    def setUp(self):
        self.student = Student("Faris")
       
    def test_creation(self):
        self.assertEqual(self.student.name, "Faris")
    def test_add_grade(self):
        self.student.add_grade(1, 90)
        self.assertEqual(self.student.grades[1], 90)
    def enroll_in_course(self):
        course = Course("Math")
        self.student.enroll_in_course(course)
        self.assertIn(course, self.student.enrolled_courses)
 
 
unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# ..
# ----------------------------------------------------------------------
# Ran 2 tests in 0.007s
#
# OK

# %%
class Course:
    _id_counter = 1

    def __init__(self, name):
        self.course_id = Course._id_counter
        Course._id_counter += 1
        self.name = name
        self.enrolled_students = []  # قائمة الطلاب المسجلين في هذا الكورس

    def __str__(self):
        return f"Course ID: {self.course_id}, Name: {self.name}, Enrolled: {len(self.enrolled_students)}"

    # تسجيل الطالب في الكورس
    def enroll_student(self, student):
        if student not in self.enrolled_students:
            self.enrolled_students.append(student)
            print(f"Student {student.name} enrolled successfully in {self.name}.")
        else:
            print(f"Student {student.name} is already enrolled in {self.name}.")

    # إزالة الطالب من الكورس الحالي
    def remove_student(self, student):
        if student in self.enrolled_students:
            self.enrolled_students.remove(student)
            print(f"Student {student.name} removed from {self.name}.")
        else:
            print(f"Student {student.name} is not enrolled in {self.name}.")
            


import unittest

class TestCourse(unittest.TestCase):

    def setUp(self):
        self.course = Course("Math")

    def test_creation(self):
        self.assertEqual(self.course.name, "Math")

    def test_enroll_student(self):
        self.course.enroll_student("ereny")
        self.assertIn("Faris", self.course.enrolled_students)

    def test_remove_student(self):
        self.course.enroll_student("ereny")
        self.course.remove_student("ereny")
        self.assertNotIn("Faris", self.course.enrolled_students)


unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# .EE..
# ...
# ERROR: test_enroll_student (__main__.TestCourse.test_enroll_student)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Maydoum\AppData\Local\Temp\ipykernel_8296\4274361468.py", line 42, in test_enroll_student
#     self.course.enroll_student("ereny")
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^
#   File "C:\Users\Maydoum\AppData\Local\Temp\ipykernel_8296\4274361468.py", line 17, in enroll_student
#     print(f"Student {student.name} enrolled successfully in {self.name}.")
#                      ^^^^^^^^^^^^
# AttributeError: 'str' object has no attribute 'name'
#
# ...
# ERROR: test_remove_student (__main__.TestCourse.test_remove_student)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Maydoum\AppData\Local\Temp\ipykernel_8296\4274361468.py", line 46, in test_remove_student
#     self.course.enroll_student("ereny")
# ...
