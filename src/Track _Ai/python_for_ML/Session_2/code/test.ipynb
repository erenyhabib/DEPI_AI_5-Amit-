# %%
list_one = [1, 2, 3, 4, "Depi", "machine learning", True, [1, 2, 3, "True", ["ml", "dl", "llm"]]]

# %%
list_one
# Out:
# [1,
#  2,
#  3,
#  4,
#  'Depi',
#  'machine learning',
#  True,
#  [1, 2, 3, 'True', ['ml', 'dl', 'llm']]]

# %%
print(type(list_one))
# Out:
# <class 'list'>

# %%
#changeable
list_one[3]=0
list_one
# Out:
# [1,
#  2,
#  3,
#  0,
#  'Depi',
#  'machine learning',
#  True,
#  [1, 2, 3, 'True', ['ml', 'dl', 'llm']]]

# %%
print(list_one[4])
# Out:
# Depi

# %%
print(list_one[7][4][0])
# Out:
# ml

# %%
#علشان اقدر احول اي حاجه ل ليست
y = list("amit")
y
# Out:
# ['a', 'm', 'i', 't']

# %% [markdown]
# Add Item To List

# %%
list_1=["Depi","ml","genai"]
list_1.append("Deep learning")
print(list_1)
# Out:
# ['Depi', 'ml', 'genai', 'Deep learning']

# %%
list_1.extend("machine")
list_1
# Out:
# ['Depi', 'ml', 'genai', 'Deep learning', 'm', 'a', 'c', 'h', 'i', 'n', 'e']

# %%
list_1.insert(0,"NLP")
list_1
# Out:
# ['NLP',
#  'Depi',
#  'ml',
#  'genai',
#  'Deep learning',
#  'm',
#  'a',
#  'c',
#  'h',
#  'i',
#  'n',
#  'e']

# %% [markdown]
# delete Item To List

# %%
list_2=["depi","ml","ai"]
list_2.pop()
print(list_2)
# Out:
# ['depi', 'ml']

# %%
list_2.pop(0)
print(list_2)
# Out:
# ['ml']

# %%
list_2.remove("ml")
list_2
# Out:
# ['depi']

# %%
del list_2[0]
print(list_2)
# Out:
# []

# %%
name=input("enter your name")
age=input("emter your age")
print(f"my name is {name} ,and my age is {age}")
# Out:
# my name is ereny ,and my age is 20

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
my_list = ["amit", "learning", "python", "machine learning", "data science", "deep learning"]

# %%
item = input("Enter the item to remove: ")

# %%
print(item)
# Out:
# python

# %%
my_list.remove(item)

# %%
print(my_list)
# Out:
# ['amit', 'learning', 'machine learning', 'data science', 'deep learning']

# %%
new_list=[1,2,3]
Index=new_list.index(2)
print(Index)
# Out:
# 1

# %%
count=new_list.count(2)
count
# Out:
# 1

# %%
list_5=[4,7,3,2,1]
list_5.sort()

# %%
list_5
# Out:
# [1, 2, 3, 4, 7]

# %%
list_5.reverse()
list_5
# Out:
# [7, 4, 3, 2, 1]

# %%
list_6=[1,2,3,4,76,6]
list_6.clear()
print(list_6)
# Out:
# []

# %% [markdown]
# Tuple

# %%
tuple_1=(1,2,3)
print(type(tuple_1))
# Out:
# <class 'tuple'>

# %% [markdown]
# convert tuple to list ...>2-add,del

# %%
tuple_of_list=list(tuple_1)
tuple_of_list
# Out:
# [1, 2, 3]

# %%
tuple_of_list.append("5")
tuple_of_list
# Out:
# [1, 2, 3, '5']

# %%
tuple_of_list.insert(0,7)
tuple_of_list
# Out:
# [7, 1, 2, 3, '5']

# %%
tuple_of_list.extend("ML")
tuple_of_list
# Out:
# [7, 1, 2, 3, '5', 'M', 'L', 'M', 'L']

# %% [markdown]
# SET

# %%
x={1,2,3}
type(x)
# Out:
# set

# %%
x2={1:"ereny"}
type(x2)
# Out:
# dict

# %%
A={1,2,3}
B={3,4,5}
print(A|B)
# Out:
# {1, 2, 3, 4, 5}

# %%
print(A.intersection(B))
# Out:
# {3}

# %% [markdown]
# Dictionary

# %%
dictionary={"key1":12,"key2":5}
print(dictionary)
# Out:
# {'key1': 12, 'key2': 5}

# %%
dictionary["key1"]="depi"

# %%
dictionary
# Out:
# {'key1': 'depi', 'key2': 5}

# %%
value_1={('a',1),('b',2)}
dict_2=dict(value_1)
print(dict_2)
print(type(dict_2))
# Out:
# {'b': 2, 'a': 1}
# <class 'dict'>

# %%
number=int(input("enter your id : "))
print(number)
# Out:
# 60

# %%
type(number)
# Out:
# int

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

print("Addition =", num1 + num2)
print("Subtraction =", num1 - num2)
print("Multiplication =", num1 * num2)
print("division =", num1 / num2)
# Out:
# Addition = 11.0
# Subtraction = -4.199999999999999
# Multiplication = 25.84
# division = 0.4473684210526316

# %% [markdown]
# if_else

# %%
a=300
b=30
if b>a:
    print(f"{b} is greater than {a}")
else:
    print(f"{a} is greater")
# Out:
# 300 is greater

# %%
x=5
y=10
if x>0 and y>0 :
    print("both greter than zero")
# Out:
# both greter than zero

# %%
degree = float(input("Enter your degree: "))

if degree >= 90:
    print("Grade: A")
elif degree >= 80:
    print("Grade: B")
elif degree >= 70:
    print("Grade: C")
elif degree >= 60:
    print("Grade: D")
else:
    print("Grade: F")
# Out:
# Grade: F
